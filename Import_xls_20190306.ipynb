# %%
import pandas as pd
import numpy as np

# %%
file = "apples.xlsx"

# %%
data = pd.ExcelFile(file)
data_array = np.array(data)
print(data_array)

# %%
data.parse("Apples")  #put sheet name in argument
# Out:
#    Apples—Average retail price per pound or pint and per cup equivalent, 2016  \
# 0                                                Form
# 1                                                 NaN
# 2                                              Fresh1
# 3                                         Applesauce2
# 4                                               Juice
# 5                                     Ready to drink3
# 6                                             Frozen4
# 7   1The USDA National Nutrient Database for Stand...
# 8                                                 NaN
# 9   2Excludes applesauce packed in individual cont...
# 10                                                NaN
# 11  3Includes refrigerated and unrefrigerated juice.
# 12                                                NaN
# 13  4Includes juice sold as frozen concentrate. Th...
# 14                                                NaN
# 15  Source: Calculated by USDA, Economic Research ...
# ...

# %%
data1 = pd.ExcelFile(file)

# %%
print(data1.sheet_names)
# Out:
# ['Apples']

# %%
df1 = data.parse(0)

# %%
print(df1)
# Out:
#    Apples—Average retail price per pound or pint and per cup equivalent, 2016  \
# 0                                                Form
# 1                                                 NaN
# 2                                              Fresh1
# 3                                         Applesauce2
# 4                                               Juice
# 5                                     Ready to drink3
# 6                                             Frozen4
# 7   1The USDA National Nutrient Database for Stand...
# 8                                                 NaN
# 9   2Excludes applesauce packed in individual cont...
# 10                                                NaN
# 11  3Includes refrigerated and unrefrigerated juice.
# 12                                                NaN
# 13  4Includes juice sold as frozen concentrate. Th...
# 14                                                NaN
# 15  Source: Calculated by USDA, Economic Research ...
# ...

# %%
print(df1.head())
# Out:
#   Apples—Average retail price per pound or pint and per cup equivalent, 2016  \
# 0                                               Form
# 1                                                NaN
# 2                                             Fresh1
# 3                                        Applesauce2
# 4                                              Juice
#
#               Unnamed: 1  Unnamed: 2    Unnamed: 3       Unnamed: 4  \
# 0  Average retail price          NaN   Preparation       Size of a
# 1                    NaN         NaN  yield factor  cup equivalent
# 2                1.61553   per pound           0.9         0.242508
# 3                 1.0491   per pound             1         0.540133
# 4                    NaN         NaN           NaN              NaN
#
#   Unnamed: 5          Unnamed: 6
# 0        NaN       Average price
# 1        NaN  per cup equivalent
# 2     pounds            0.435312
# 3     pounds            0.566653
# 4        NaN                 NaN

# %%
df2 = file.parse(0, parse_cols=[0],skiprows=[0], names=["Country"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a6c126ea565f> in <module>
# ----> 1 df2 = file.parse(0, parse_cols=[0],skiprows=[0], names=["Country"])
#
# AttributeError: 'str' object has no attribute 'parse'

# %%
print(df2.head())
